# %%
import pandas as pd
import requests
import os
import asyncio

import json
import time

from src import agent_llm

# %%
import asyncio
from typing import List, Dict, Any
import pandas as pd

from src.agent_llm import SmartAgentSystem

async def process_batch(batch: List[str]) -> List[Dict[str, Any]]:
    """Processa um batch de comentários usando o SmartAgentSystem"""
    async with SmartAgentSystem() as agent:
        tasks = [agent.expert_agent(comment) for _, comment in batch]
        results = await asyncio.gather(*tasks)
        
        # Associa cada resultado ao texto original e índice
        return [
            {
                "original_index": idx,
                "original_text": text,
                "sentiment": result.get("sentiment") if result else None,
                "metadata": result.get("metadata") if result else None,
                "raw_response": result
            }
            for (idx, text), result in zip(batch, results)
        ]
        

async def process_comments_in_batches(comments: List[str], batch_size: int = 10) -> List[Dict[str, Any]]:
    """Processa todos os comentários em batches assíncronos mantendo a associação completa"""
    all_results = []
    
    # Adiciona índices para rastreamento
    indexed_comments = list(enumerate(comments))
    
    for i in range(0, len(indexed_comments), batch_size):
        batch = indexed_comments[i:i + batch_size]
        print(f"Processando batch {i//batch_size + 1} ({i+1}-{min(i+batch_size, len(comments))} de {len(comments)})")
        
        try:
            batch_results = await process_batch(batch)
            all_results.extend(batch_results)
            
            # Pequena pausa entre batches
            await asyncio.sleep(3)
        except Exception as e:
            print(f"Erro no batch {i//batch_size + 1}: {str(e)}")
            # Adiciona registros vazios para os itens falhos mantendo a ordem
            all_results.extend([
                {
                    "original_index": idx,
                    "original_text": text,
                    "sentiment": None,
                    "metadata": None,
                    "raw_response": None
                }
                for idx, text in batch
            ])
    
    return sorted(all_results, key=lambda x: x["original_index"])  # Garante ordem original  

def expand_results_to_dataframe(df: pd.DataFrame, results: List[Dict[str, Any]]) -> pd.DataFrame:
    """Expande os resultados completos para o DataFrame original"""
    # Cria DataFrame com os resultados
    results_df = pd.DataFrame(results)
    
    # Remove colunas temporárias que não queremos manter
    results_df.drop(columns=['original_index', 'original_text'], inplace=True, errors='ignore')
    
    # Junta com o DataFrame original
    expanded_df = df.copy()
    expanded_df = pd.concat([expanded_df, results_df], axis=1)
    
    # Expande os metadados em colunas separadas
    if 'metadata' in expanded_df.columns:
        metadata_df = expanded_df['metadata'].apply(
            lambda x: pd.Series(x) if isinstance(x, dict) else pd.Series()
        )
        metadata_df = metadata_df.add_prefix('metadata_')
        expanded_df = pd.concat([expanded_df.drop(columns=['metadata']), metadata_df], axis=1)
    
    return expanded_df

# %%
df_train = pd.read_parquet('dataset_train_cleaned.parquet').head(20) # Exemplo carregando do Parquet limpo
# Supondo que df_train é seu DataFrame com os comentários
comments_to_process = df_train['comment_cleaned'].tolist()  # Corrigi o nome da coluna para 'comment_cleaned'

# %%
comments_to_process
# Out:
# ['judging from previous posts this used to be a good place , but not any longer .;',
#  'we , there were four of us , arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude .;',
#  'they never brought us complimentary noodles , ignored repeated requests for sugar , and threw our dishes on the table .;',
#  'the food was lousy - too sweet or too salty and the portions tiny .;',
#  'after all that , they complained to me about the small tip .;',
#  'avoid this place !;',
#  'i have eaten at saul , many times , the food is always consistently , outrageously good .;',
#  'saul is the best restaurant on smith street and in brooklyn .;',
#  'the duck confit is always amazing and the foie gras terrine with figs was out of this world .;',
#  'the wine list is interesting and has many good values .;',
#  'for the price , you can not eat this well in manhattan .;',
#  'i was very disappointed with this restaurant .;',
#  'ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away .;',
#  'i had to ask her three times before she finally came back with the dish ive requested .;',
#  'food was okay , nothing great .;',
#  'chow fun was dry ; pork shu mai was more than usually greasy and had to share a table with loud and rude family .',
#  'i / we will never go back to this place again .;',
#  'went on a 3 day oyster binge , with fish bringing up the closing , and i am so glad this was the place it o trip ended , because it was so great !;',
#  "service was devine , oysters where a sensual as they come , and the price ca n ' t be beat ! ! !;",
#  "you ca n ' t go wrong here .;"]

# %%
# Processa todos os comentários em batches de 10
results = await process_comments_in_batches(comments_to_process)

# Adiciona os resultados de volta ao DataFrame
df_train['sentiment_result'] = results
# Out:
# Processando batch 1 (1-10 de 20)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'high-quality dishes'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'consistently good food'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'strong warning'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'food quality and portion size'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'poor service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'staff', 'reason': 'rude behavior'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'customer', 'reason': 'unreasonable expectation about tip'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'decline in quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good values on wine list'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'highly recommended'}}
# Processando batch 2 (11-20 de 20)
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mediocre experience'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'disappointment'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'excellent service, great food, good value'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'cart attendant', 'reason': 'unhelpful service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'overall experience', 'reason': 'strongly negative statement indicating no intention to return'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'slow service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'endorsement'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'value for money'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'dry chow fun, greasy pork shu mai, unpleasant dining companions'}}

# %%
# Expande os resultados para o DataFrame original
final_df = expand_results_to_dataframe(df_train, results)

# %%
final_df
# Out:
#                                               comment  \
# 0   judging from previous posts this used to be a ...
# 1   we , there were four of us , arrived at noon -...
# 2   they never brought us complimentary noodles , ...
# 3   the food was lousy - too sweet or too salty an...
# 4   after all that , they complained to me about t...
# 5                                 avoid this place !;
# 6   i have eaten at saul , many times , the food i...
# 7   saul is the best restaurant on smith street an...
# 8   the duck confit is always amazing and the foie...
# 9   the wine list is interesting and has many good...
# 10  for the price , you can not eat this well in m...
# 11    i was very disappointed with this restaurant .;
# 12  ive asked a cart attendant for a lotus leaf wr...
# 13  i had to ask her three times before she finall...
# 14                   food was okay , nothing great .;
# 15  chow fun was dry ; pork shu mai was more than ...
# 16   i / we will never go back to this place again .;
# 17  went on a 3 day oyster binge , with fish bring...
# 18  service was devine , oysters where a sensual a...
# 19                      you ca n ' t go wrong here .;
#
#                                       comment_cleaned  \
# 0   judging from previous posts this used to be a ...
# 1   we , there were four of us , arrived at noon -...
# 2   they never brought us complimentary noodles , ...
# 3   the food was lousy - too sweet or too salty an...
# 4   after all that , they complained to me about t...
# 5                                 avoid this place !;
# 6   i have eaten at saul , many times , the food i...
# 7   saul is the best restaurant on smith street an...
# 8   the duck confit is always amazing and the foie...
# 9   the wine list is interesting and has many good...
# 10  for the price , you can not eat this well in m...
# 11    i was very disappointed with this restaurant .;
# 12  ive asked a cart attendant for a lotus leaf wr...
# 13  i had to ask her three times before she finall...
# 14                   food was okay , nothing great .;
# 15  chow fun was dry ; pork shu mai was more than ...
# 16   i / we will never go back to this place again .;
# 17  went on a 3 day oyster binge , with fish bring...
# 18  service was devine , oysters where a sensual a...
# 19                      you ca n ' t go wrong here .;
#
#                                      sentiment_result sentiment sentiment  \
# 0   {'original_index': 0, 'original_text': 'judgin...  Negative  Negative
# 1   {'original_index': 1, 'original_text': 'we , t...  Negative  Negative
# 2   {'original_index': 2, 'original_text': 'they n...  Negative  Negative
# 3   {'original_index': 3, 'original_text': 'the fo...  Negative  Negative
# 4   {'original_index': 4, 'original_text': 'after ...  Negative  Negative
# 5   {'original_index': 5, 'original_text': 'avoid ...  Negative  Negative
# 6   {'original_index': 6, 'original_text': 'i have...  Positive  Positive
# 7   {'original_index': 7, 'original_text': 'saul i...  Positive  Positive
# 8   {'original_index': 8, 'original_text': 'the du...  Positive  Positive
# 9   {'original_index': 9, 'original_text': 'the wi...  Positive  Positive
# 10  {'original_index': 10, 'original_text': 'for t...  Positive  Positive
# 11  {'original_index': 11, 'original_text': 'i was...  Negative  Negative
# 12  {'original_index': 12, 'original_text': 'ive a...  Negative  Negative
# 13  {'original_index': 13, 'original_text': 'i had...  Negative  Negative
# 14  {'original_index': 14, 'original_text': 'food ...   Neutral   Neutral
# 15  {'original_index': 15, 'original_text': 'chow ...  Negative  Negative
# 16  {'original_index': 16, 'original_text': 'i / w...  Negative  Negative
# 17  {'original_index': 17, 'original_text': 'went ...  Positive  Positive
# 18  {'original_index': 18, 'original_text': 'servi...  Positive  Positive
# 19  {'original_index': 19, 'original_text': 'you c...  Positive  Positive
#
#                                          raw_response  \
# 0   {'sentiment': 'Negative', 'metadata': {'reason...
# 1   {'sentiment': 'Negative', 'metadata': {'respon...
# 2   {'sentiment': 'Negative', 'metadata': {'respon...
# 3   {'sentiment': 'Negative', 'metadata': {'reason...
# 4   {'sentiment': 'Negative', 'metadata': {'respon...
# 5   {'sentiment': 'Negative', 'metadata': {'reason...
# 6   {'sentiment': 'Positive', 'metadata': {'reason...
# 7   {'sentiment': 'Positive', 'metadata': {'respon...
# 8   {'sentiment': 'Positive', 'metadata': {'reason...
# 9   {'sentiment': 'Positive', 'metadata': {'reason...
# 10  {'sentiment': 'Positive', 'metadata': {'reason...
# 11  {'sentiment': 'Negative', 'metadata': {'reason...
# 12  {'sentiment': 'Negative', 'metadata': {'respon...
# 13  {'sentiment': 'Negative', 'metadata': {'respon...
# 14  {'sentiment': 'Neutral', 'metadata': {'reason'...
# 15  {'sentiment': 'Negative', 'metadata': {'reason...
# 16  {'sentiment': 'Negative', 'metadata': {'respon...
# 17  {'sentiment': 'Positive', 'metadata': {'reason...
# 18  {'sentiment': 'Positive', 'metadata': {'respon...
# 19  {'sentiment': 'Positive', 'metadata': {'reason...
#
#                                       metadata_reason metadata_responsible
# 0                                  decline in quality                  NaN
# 1                                       rude behavior                staff
# 2                                        poor service               waiter
# 3                       food quality and portion size                  NaN
# 4                  unreasonable expectation about tip             customer
# 5                                      strong warning                  NaN
# 6                              consistently good food                  NaN
# 7                                  highly recommended   overall experience
# 8                                 high-quality dishes                  NaN
# 9                            good values on wine list                  NaN
# 10                                    value for money                  NaN
# 11                                     disappointment                  NaN
# 12                                  unhelpful service       cart attendant
# 13                                       slow service               waiter
# 14                                mediocre experience                  NaN
# 15  dry chow fun, greasy pork shu mai, unpleasant ...                  NaN
# 16  strongly negative statement indicating no inte...   overall experience
# 17                                   great experience                  NaN
# 18          excellent service, great food, good value   overall experience
# 19                                        endorsement                  NaN

# %%
# Carrega os dados do arquivo Parquet
df_train = pd.read_parquet('dataset_train_cleaned.parquet')

# Verifica se a coluna existe
if 'comment_cleaned' not in df_train.columns:
    raise ValueError("O DataFrame não contém a coluna 'comment_cleaned'")

comments_to_process = df_train['comment_cleaned'].tolist()

# Processa todos os comentários em batches de 10
print(f"Iniciando processamento de {len(comments_to_process)} comentários...")
results = await process_comments_in_batches(comments_to_process)

# Expande os resultados para o DataFrame original
final_df = expand_results_to_dataframe(df_train, results)

# Salva os resultados em um novo arquivo Parquet
output_path = 'dataset_train_with_sentiment.parquet'
final_df.to_parquet(output_path, index=False)
print(f"Processamento concluído! Resultados salvos em {output_path}")
print("\nResumo dos resultados:")
print(final_df[['sentiment', 'metadata_responsible', 'metadata_reason']].head())
print(f"\nTotal de comentários processados: {len(results)}")
# Out:
# Iniciando processamento de 651 comentários...
# Processando batch 1 (1-10 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent dishes'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'strong warning to others'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'food quality and portion size'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good values on wine list'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'staff', 'reason': 'rude behavior'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall', 'reason': 'highly recommended'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'poor service, ignored requests, and rude handling of dishes'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'customer', 'reason': 'unreasonable expectation about tip'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'decline in quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'consistently good food'}}
# Processando batch 2 (11-20 de 651)
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'strong negative intention to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'strong endorsement'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mediocre experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'value for money'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great experience', 'subject': 'oyster binge and fish dinner'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'slow service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'excellent service, high-quality food, and good value'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'disappointment', 'responsible': 'restaurant'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'cart attendant', 'reason': 'unhelpful service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'dry chow fun, greasy pork shu mai, and unpleasant dining environment'}}
# Processando batch 3 (21-30 de 651)
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'unlikely to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'innovative and tasty dish'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'dirty vent in the ceiling'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality', 'dish': 'duck breast special'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'restaurant', 'reason': 'repeated visits'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'service staff', 'reason': 'great service after 9:30 on a Friday'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'description of a favorable location'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'too sweet dishes', 'dish_type': 'Thai fusion'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'food quality, service, and decor'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'Mixed sentiment, but overall leaning towards neutral due to limited positive aspect and lack of strong negative sentiment'}}
# Processando batch 4 (31-40 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'unique experience, welcoming atmosphere'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'responsible': 'waiter', 'reason': 'intimidating behavior'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'decent is a neutral descriptor'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'service', 'reason': 'bad service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'management', 'reason': 'not found'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'relaxed and stylish ambiance'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter', 'reason': 'friendly and attentive service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'inattentive service'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': "only describes the restaurant's occupancy without expressing a clear opinion"}}
# Processando batch 5 (41-50 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'fresh and adequately proportioned food'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'descriptive statement without clear opinion'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'description of a pleasant culinary experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good rice to fish ratio, not overpacking rice'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall', 'reason': 'great experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'service staff', 'reason': 'top notch service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'repeat visits'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good value for money', 'specific_offer': 'half price sushi deal'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'contradiction to expectation'}}
# Processando batch 6 (51-60 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great dishes'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'description of a peaceful atmosphere'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'terrific experience and good value'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed sentiments about service quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter and chef', 'reason': 'impecable service and well prepared food'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'restaurant', 'reason': 'poor quality or service implied by sarcasm'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'affordable price and fresh, continually refilled food'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'responsible': 'food', 'reason': 'mixed opinions on different dishes'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'intention to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'intention to return and recommend'}}
# Processando batch 7 (61-70 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praising ambience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'pleasant atmosphere comparison'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'descriptive statement without opinion'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'cozy atmosphere with Parisian flair'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'undercooked or improperly prepared food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great service, great food, reasonable price'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'delivery', 'reason': 'cold pizza and unmelted cheese'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'dessert', 'reason': 'incredible lava cake'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed assessment of different dishes, overall average experience'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 
}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality', 'dish': "Pam's special fried fish"}}
# Processando batch 27 (261-270 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'implying a good experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'establishment', 'reason': 'fine'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'limited choices and not worth the price'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great value for money and quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'reasonable price', 'price_range': '$3-6'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'responsible': 'waiters and atmosphere', 'reason': 'mixed impressions of atmosphere and service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'great price, food, and service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good food', 'dish': 'yellowtail'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'intention to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'kitchen', 'reason': 'quick and efficient preparation'}}
# Processando batch 28 (271-280 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'amazing time'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'delicious desserts'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'overall satisfaction'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'high quality takeout and tupperware'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'staff, food, ambiance', 'reason': 'accommodating staff, delicious food, lovely place'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'willingness to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'manager', 'reason': 'attentive and ensured customer enjoyment'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'worth the high prices'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'kitchen', 'reason': 'timely and fresh pasta dish'}}
# Processando batch 29 (281-290 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'no negative aspects mentioned'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'delicious with goat cheese and panchetta'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed sentiments with no clear overall sentiment'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'cozy atmosphere and good pizza'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'tasty drink suitable for the weather'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'comment describes the type of food without expressing a clear opinion or emotion'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'inconsistency'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'kitchen/chef', 'reason': 'taste'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed sentiments with no clear overall opinion'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'descriptive text without emotional tone'}}
# Processando batch 30 (291-300 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'relaxing atmosphere'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'terrific pizza and homemade pasta'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed and neutral observations'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'eagerness to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'delicious and authentic food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'recommendation and willingness to return'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'ambience, service', 'reason': 'delightful ambience, impeccable service'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'responsible': 'staff', 'reason': 'mixed experience with slow service but friendly people'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'comment only describes the drink order without expressing opinion'}}
# Processando batch 31 (301-310 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'strong affection'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'recommendation'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'intention to return and high preference'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'restaurant', 'reason': 'poor service and ambience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'dish', 'reason': 'filet mignon was superb'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'liked the ambience'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'negative opinion on the crowd and implied quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent food and service', 'responsible': 'overall experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent food quality', 'dish': 'sushi'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'description of the restaurant as cute'}}
# Processando batch 32 (311-320 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good hang out spot'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'anticipation of a pleasant experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'strong endorsement'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'affordable price and good ambiance'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'value for money'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'disappointment'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'bad meal experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'had a great time'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'dishes not authentic to Thai cuisine'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'encouraging tone'}}
# Processando batch 33 (321-330 de 651)
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'overcooked food', 'dish': 'fish'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'multiple deficiencies despite good food', 'responsible': 'overall experience'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'service', 'reason': 'not meeting price category expectations'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'poor service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'improper service despite friendly gestures'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'ambiance', 'reason': 'noise level'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'expensive wine options, limited affordable selection'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'overcrowding, unoriginal menu, overpriced wine list'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'food quality and flavoring issues', 'responsible': 'kitchen/chef'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'discrepancy between claim and actual experience', 'claimed_attribute': 'romantic'}}
# Processando batch 34 (331-340 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent food quality'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'big disappointment'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'favorite restaurant, disagreeing with negative reviews'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'recommendation'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'comment is more of a statement without clear opinion or sentiment'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'overall negative tone', 'responsible': 'overall experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'staff', 'reason': 'cool ambiance, prompt and courteous service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'overall experience', 'reason': 'would never go there again'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter and chef', 'reason': 'good service and fresh food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': "pizza quality exceeds expectations from a pizzeria owner's family member"}}
# Processando batch 35 (341-350 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great food, great service, pleasant atmosphere'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'genuine dining experience'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'factual description without opinion'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'pleasant ambiance'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'staff', 'reason': 'impeccable service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'implying a favorite or frequent visit'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praise for food freshness and preparation'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'breathtaking view, top notch service, wonderful ambiance'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'staff', 'reason': 'impeccable and unobtrusive service, knowledgeable about menu, attentive to needs'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'comparing dishes and expressing a positive opinion on at least one'}}
# Processando batch 36 (351-360 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'flavor and texture'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'enthusiastic recommendation'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praising the food'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed sentiment, spicy but not offensive'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 
quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent pesto pizza, nice amount of spicy italian cheese, thin crust'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'expensive', 'price': '$15 each'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'only describes food without expressing opinion'}}
# Processando batch 60 (591-600 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'authentic and yummy food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'liking for the food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'bartender', 'reason': 'good martinis'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'large portion and good food quality, specifically french fries'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'overall satisfaction'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'food quality', 'dish': 'lobster sandwich'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'dish', 'reason': 'delicious scallops and wonderful sauce'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good value for money'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'pleasant atmosphere and personal herb garden'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'location'}}
# Processando batch 61 (601-610 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'rare gem in NY'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'low price'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'unique, tasty, and fresh dishes, exceptional pistachio ice cream'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'suitable for special occasions'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praising quality and delivery speed'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'exceeded expectations with variety of dishes and pleased with every choice'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'responsible': 'delivery service', 'reason': 'mixed experience with food quality and delivery'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter/chef', 'reason': 'excellent service and delicious food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'good food, good size menu, great service, unpretentious setting'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'kitchen', 'reason': 'long wait time'}}
# Processando batch 62 (611-620 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter', 'reason': 'recommended dessert'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'presentation and variety'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'friend', 'reason': 'recommendation'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'staff', 'reason': 'excellent service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'restaurant management', 'reason': 'out of stock'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'kitchen/staff', 'reason': 'slow service, poor food quality'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter/server', 'reason': 'helpful in suggesting drinks and dishes'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'staff', 'reason': 'abrupt behavior and unconvincing excuse'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter', 'reason': 'prompt greeting, nice and cordial'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'overall experience', 'reason': 'wonderful place, value for money'}}
# Processando batch 63 (621-630 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'strong recommendation'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'pleasant ambiance'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'suitable for social occasions'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'high praise'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'dish', 'reason': 'filet was very good'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'intention to revisit'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter and chef', 'reason': 'outstanding food, quick, friendly and professional service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter', 'reason': 'great service and fantastic food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praising the pizza place'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'The comment does not express a clear opinion or sentiment, it appears to be a directive or suggestion without any emotional tone.'}}
# Processando batch 64 (631-640 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'best pizza in manhattan'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'praising the restaurant as one of the best'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'recommendation', 'dish': 'Sophia Pizza'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'horrible service'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'great food and good price'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'excellent food or experience'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'descriptive statement without opinion'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'pizzeria', 'reason': 'great'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'kitchen', 'reason': 'fresh food'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'multiple', 'reason': 'thin crust, fresh ingredients, friendly staff'}}
# Processando batch 65 (641-650 de 651)
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': 'mixed experience'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'soothing decor, excellent sake, great service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'bad food and service'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'reason': 'rushed out unnecessarily', 'responsible': 'staff'}}
# Expert Agent Decision: {'sentiment': 'Negative', 'metadata': {'responsible': 'waiter', 'reason': 'rude behavior'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'unique and creative rolls'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'waiter and chef', 'reason': 'attentive and charming service, best cuisine'}}
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'responsible': 'kitchen', 'reason': 'delicious food and exceptional sushi'}}
# Expert Agent Decision: {'sentiment': 'Neutral', 'metadata': {'reason': "The comment is neutral as it doesn't express a clear opinion or sentiment, but rather indicates a future intention to revisit and judge."}}
# Processando batch 66 (651-651 de 651)
# Expert Agent Decision: {'sentiment': 'Positive', 'metadata': {'reason': 'high praise and comparison to other restaurants'}}
# Processamento concluído! Resultados salvos em dataset_train_with_sentiment.parquet
#
# Resumo dos resultados:
#   sentiment metadata_responsible  \
# 0  Negative                  NaN
# 1  Negative                staff
# 2  Negative               waiter
# 3  Negative                  NaN
# 4  Negative             customer
#
#                                      metadata_reason
# 0                                 decline in quality
# 1                                      rude behavior
# 2  poor service, ignored requests, and rude handl...
# 3                      food quality and portion size
# 4                 unreasonable expectation about tip
#
# Total de comentários processados: 651
